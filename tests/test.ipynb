# %%
from rag_system import RAGSystem
import os

# %%
rag = RAGSystem(
        persist_directory="./chroma_db",
        collection_name="my_documents",
        openai_api_key=os.getenv("OPENAI_API_KEY"),
        embedding_model_name="sentence-transformers/all-MiniLM-L6-v2"
    )
# Out:
# /Users/fiore/Projects/wow-rag/rag_system.py:64: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   self.embeddings = HuggingFaceEmbeddings(
# /Users/fiore/Projects/wow-rag/rag_system.py:70: LangChainDeprecationWarning: The class `Chroma` was deprecated in LangChain 0.2.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-chroma package and should be used instead. To use it run `pip install -U :class:`~langchain-chroma` and import as `from :class:`~langchain_chroma import Chroma``.
#   self.vector_store = Chroma(
# /Users/fiore/Projects/wow-rag/rag_system.py:77: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import ChatOpenAI``.
#   self.llm = ChatOpenAI(

# %%
# Add sample documents
documents = [
    "Machine learning is a subset of artificial intelligence that focuses on algorithms that can learn from data.",
    "Deep learning uses neural networks with multiple layers to model and understand complex patterns.",
    "Natural language processing enables computers to understand and generate human language."
]
sources = ["ml_doc", "dl_doc", "nlp_doc"]
rag.add_documents(documents, sources=sources)

# Query the system
response = rag.query("What is machine learning?")
print("Answer:", response)

# Get system statistics
stats = rag.get_stats()
print("System stats:", stats)
# Out:
# Added 3 chunks from 3 documents
# QA chain initialized
# Answer: {'answer': 'Machine learning is a subset of artificial intelligence that focuses on algorithms that can learn from data.', 'question': 'What is machine learning?', 'sources': [{'content': 'Machine learning is a subset of artificial intelligence that focuses on algorithms that can learn from data.', 'metadata': {'source': 'ml_doc', 'chunk_id': 0, 'doc_id': 0}}, {'content': 'Machine learning is a subset of artificial intelligence that focuses on algorithms that can learn from data.', 'metadata': {'source': 'ml_doc', 'doc_id': 0, 'chunk_id': 0}}, {'content': 'Machine learning is a subset of artificial intelligence that focuses on algorithms that can learn from data.', 'metadata': {'chunk_id': 0, 'doc_id': 0, 'source': 'ml_doc'}}, {'content': 'Machine learning is a subset of artificial intelligence that focuses on algorithms that can learn from data.', 'metadata': {'chunk_id': 0, 'doc_id': 0, 'source': 'ml_doc'}}]}
# System stats: {'collection_name': 'my_documents', 'persist_directory': './chroma_db', 'chunk_size': 1000, 'chunk_overlap': 200, 'embedding_model': 'sentence-transformers/all-MiniLM-L6-v2', 'qa_chain_initialized': True, 'document_count': 27}

# %%
rag.query("What is machine learning?")
# Out:
# {'answer': "I don't know based on the given context.",
#  'question': 'What is machine learning?',
#  'sources': [{'content': 'Deep learning uses neural networks with multiple layers to model and understand complex patterns.',
#    'metadata': {'source': 'dl_doc', 'chunk_id': 0, 'doc_id': 1}},
#   {'content': 'Deep learning uses neural networks with multiple layers to model and understand complex patterns.',
#    'metadata': {'chunk_id': 0, 'doc_id': 1, 'source': 'dl_doc'}},
#   {'content': 'Deep learning uses neural networks with multiple layers to model and understand complex patterns.',
#    'metadata': {'chunk_id': 0, 'doc_id': 1, 'source': 'dl_doc'}},
#   {'content': 'Deep learning uses neural networks with multiple layers to model and understand complex patterns.',
#    'metadata': {'doc_id': 1, 'source': 'dl_doc', 'chunk_id': 0}}]}

# %%
rag.vector_store.get().keys()
# Out:
# dict_keys(['ids', 'embeddings', 'documents', 'uris', 'included', 'data', 'metadatas'])

# %%
rag.get_document(1)
# Out:
# {'content': 'Deep learning uses neural networks with multiple layers to model and understand complex patterns.',
#  'metadata': {'chunk_id': 0, 'source': 'dl_doc', 'doc_id': 1}}

# %%
rag.delete_document(0)
# Out:
# Deleted document with doc_id=0
# True

# %%
rag.get_all_documents()
# Out:
# [{'content': 'Deep learning uses neural networks with multiple layers to model and understand complex patterns.',
#   'metadata': {'doc_id': 1, 'source': 'dl_doc', 'chunk_id': 0}},
#  {'content': 'Natural language processing enables computers to understand and generate human language.',
#   'metadata': {'doc_id': 2, 'source': 'nlp_doc', 'chunk_id': 0}},
#  {'content': 'Deep learning uses neural networks with multiple layers to model and understand complex patterns.',
#   'metadata': {'doc_id': 1, 'source': 'dl_doc', 'chunk_id': 0}},
#  {'content': 'Natural language processing enables computers to understand and generate human language.',
#   'metadata': {'source': 'nlp_doc', 'chunk_id': 0, 'doc_id': 2}},
#  {'content': 'Deep learning uses neural networks with multiple layers to model and understand complex patterns.',
#   'metadata': {'doc_id': 1, 'source': 'dl_doc', 'chunk_id': 0}},
#  {'content': 'Natural language processing enables computers to understand and generate human language.',
#   'metadata': {'chunk_id': 0, 'doc_id': 2, 'source': 'nlp_doc'}},
#  {'content': 'Deep learning uses neural networks with multiple layers to model and understand complex patterns.',
#   'metadata': {'source': 'dl_doc', 'chunk_id': 0, 'doc_id': 1}},
#  {'content': 'Natural language processing enables computers to understand and generate human language.',
#   'metadata': {'source': 'nlp_doc', 'doc_id': 2, 'chunk_id': 0}},
#  {'content': 'Deep learning uses neural networks with multiple layers to model and understand complex patterns.',
#   'metadata': {'source': 'dl_doc', 'chunk_id': 0, 'doc_id': 1}},
#  {'content': 'Natural language processing enables computers to understand and generate human language.',
#   'metadata': {'doc_id': 2, 'chunk_id': 0, 'source': 'nlp_doc'}},
#  {'content': 'Deep learning uses neural networks with multiple layers to model and understand complex patterns.',
#   'metadata': {'doc_id': 1, 'source': 'dl_doc', 'chunk_id': 0}},
#  {'content': 'Natural language processing enables computers to understand and generate human language.',
#   'metadata': {'doc_id': 2, 'source': 'nlp_doc', 'chunk_id': 0}},
#  {'content': 'Deep learning uses neural networks with multiple layers to model and understand complex patterns.',
#   'metadata': {'doc_id': 1, 'source': 'dl_doc', 'chunk_id': 0}},
#  {'content': 'Natural language processing enables computers to understand and generate human language.',
#   'metadata': {'chunk_id': 0, 'source': 'nlp_doc', 'doc_id': 2}},
#  {'content': 'Deep learning uses neural networks with multiple layers to model and understand complex patterns.',
#   'metadata': {'source': 'dl_doc', 'chunk_id': 0, 'doc_id': 1}},
#  {'content': 'Natural language processing enables computers to understand and generate human language.',
#   'metadata': {'doc_id': 2, 'chunk_id': 0, 'source': 'nlp_doc'}},
#  {'content': 'Deep learning uses neural networks with multiple layers to model and understand complex patterns.',
#   'metadata': {'doc_id': 1, 'chunk_id': 0, 'source': 'dl_doc'}},
#  {'content': 'Natural language processing enables computers to understand and generate human language.',
#   'metadata': {'doc_id': 2, 'chunk_id': 0, 'source': 'nlp_doc'}}]

# %%
collection_data = rag.vector_store.get()

for doc, metadata in zip(collection_data['documents'], collection_data['metadatas']):
    print(f"Document: {doc[:100]}...")  # Print first 100 characters of each document
    print(f"Metadata: {metadata}")  # Print metadata for each document
# Out:
# Document: Machine learning is a subset of artificial intelligence that focuses on algorithms that can learn fr...
# Metadata: {'source': 'ml_doc', 'doc_id': 0, 'chunk_id': 0}
# Document: Deep learning uses neural networks with multiple layers to model and understand complex patterns....
# Metadata: {'source': 'dl_doc', 'doc_id': 1, 'chunk_id': 0}
# Document: Natural language processing enables computers to understand and generate human language....
# Metadata: {'source': 'nlp_doc', 'doc_id': 2, 'chunk_id': 0}
# Document: Machine learning is a subset of artificial intelligence that focuses on algorithms that can learn fr...
# Metadata: {'source': 'ml_doc', 'doc_id': 0, 'chunk_id': 0}
# Document: Deep learning uses neural networks with multiple layers to model and understand complex patterns....
# Metadata: {'doc_id': 1, 'source': 'dl_doc', 'chunk_id': 0}
# Document: Natural language processing enables computers to understand and generate human language....
# Metadata: {'chunk_id': 0, 'source': 'nlp_doc', 'doc_id': 2}
# Document: Machine learning is a subset of artificial intelligence that focuses on algorithms that can learn fr...
# Metadata: {'source': 'ml_doc', 'chunk_id': 0, 'doc_id': 0}
# Document: Deep learning uses neural networks with multiple layers to model and understand complex patterns....
# Metadata: {'chunk_id': 0, 'doc_id': 1, 'source': 'dl_doc'}
# Document: Natural language processing enables computers to understand and generate human language....
# Metadata: {'chunk_id': 0, 'doc_id': 2, 'source': 'nlp_doc'}
# Document: Machine learning is a subset of artificial intelligence that focuses on algorithms that can learn fr...
# Metadata: {'doc_id': 0, 'chunk_id': 0, 'source': 'ml_doc'}
# Document: Deep learning uses neural networks with multiple layers to model and understand complex patterns....
# Metadata: {'source': 'dl_doc', 'doc_id': 1, 'chunk_id': 0}
# Document: Natural language processing enables computers to understand and generate human language....
# Metadata: {'chunk_id': 0, 'source': 'nlp_doc', 'doc_id': 2}
# Document: Machine learning is a subset of artificial intelligence that focuses on algorithms that can learn fr...
# Metadata: {'doc_id': 0, 'source': 'ml_doc', 'chunk_id': 0}
# Document: Deep learning uses neural networks with multiple layers to model and understand complex patterns....
# Metadata: {'doc_id': 1, 'chunk_id': 0, 'source': 'dl_doc'}
# Document: Natural language processing enables computers to understand and generate human language....
# Metadata: {'chunk_id': 0, 'source': 'nlp_doc', 'doc_id': 2}
# Document: Machine learning is a subset of artificial intelligence that focuses on algorithms that can learn fr...
# Metadata: {'chunk_id': 0, 'source': 'ml_doc', 'doc_id': 0}
# Document: Deep learning uses neural networks with multiple layers to model and understand complex patterns....
# Metadata: {'doc_id': 1, 'source': 'dl_doc', 'chunk_id': 0}
# Document: Natural language processing enables computers to understand and generate human language....
# Metadata: {'doc_id': 2, 'chunk_id': 0, 'source': 'nlp_doc'}
# Document: Machine learning is a subset of artificial intelligence that focuses on algorithms that can learn fr...
# Metadata: {'doc_id': 0, 'source': 'ml_doc', 'chunk_id': 0}
# Document: Deep learning uses neural networks with multiple layers to model and understand complex patterns....
# Metadata: {'chunk_id': 0, 'source': 'dl_doc', 'doc_id': 1}
# Document: Natural language processing enables computers to understand and generate human language....
# Metadata: {'chunk_id': 0, 'doc_id': 2, 'source': 'nlp_doc'}
# Document: Machine learning is a subset of artificial intelligence that focuses on algorithms that can learn fr...
# Metadata: {'source': 'ml_doc', 'doc_id': 0, 'chunk_id': 0}
# Document: Deep learning uses neural networks with multiple layers to model and understand complex patterns....
# Metadata: {'doc_id': 1, 'source': 'dl_doc', 'chunk_id': 0}
# Document: Natural language processing enables computers to understand and generate human language....
# Metadata: {'source': 'nlp_doc', 'doc_id': 2, 'chunk_id': 0}
